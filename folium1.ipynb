# %% [markdown]
# <a href="https://colab.research.google.com/github/katreparitosh/Folium-Python/blob/master/folium1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium

# %%
capital_map =  folium.Map()

# %%
capitals = [
    {'loc': [25.1833,  85.5333], 'label': 'Bihar:Patna '},
    {'loc': [26.8467, 80.9462], 'label': 'Uttar Pradesh: Lucknow'},
    {'loc': [15.9129,  79.7400], 'label': 'Andhra Pradesh:Hyderabad'},
    {'loc': [18.1124,  79.0193], 'label': 'Telangana:Hyderabad'},
    {'loc': [23.6102,  85.2799], 'label': 'Jharkahnd:Ranchi'},
    {'loc': [28.2180,  94.7278], 'label': 'Arunachal Pradesh:Itanagar'},
    {'loc': [32.7266,  74.8570], 'label': 'Jammu & Kashmir: Srinagar'},
    {'loc': [31.1048,  77.1734], 'label': 'Himachal Pradesh: Shimla'},
    {'loc': [31.1471,  75.3412], 'label': 'Punjab:Chandigarh'},
    {'loc': [29.0588,  76.0856], 'label': 'Haryana:Chandigarh'},
    {'loc': [30.0668,  79.0193], 'label': 'Uttarakhand:Dehradun'},
    {'loc': [27.0238,  74.2179], 'label': 'Rajasthan:Jaipur'},
    {'loc': [22.2587,  71.1924], 'label': 'Gujrat:Gandhinagar'},
    {'loc': [27.5330,  88.5122], 'label': 'Sikkim:Gangtok'},
    {'loc': [19.7515, 75.7139], 'label': 'Maharashtra:Mumbai'}]

# %%
for state in capitals:
    marker = folium.Marker(location=state['loc'], popup=state['label'])
    marker.add_to(capital_map)

# %%
capital_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
